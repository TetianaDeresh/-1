# %%
# Таблиця заміни для S-блоку №7 згідно з стандартом DES
S7 = [
    [4,	11,	2,	14,	15,	0,	8,	13,	3,	12,	9,	7,	5,	10,	6,	1],
    [13,	0,	11,	7,	4,	9,	1,	10,	14,	3,	5,	12,	2,	15,	8,	6],
    [1,	4,	11,	13,	12,	3,	7,	14,	10,	15,	6,	8,	0,	5,	9,	2],
    [6,	11,	13,	8,	1,	4,	10,	7,	9,	5,	0,	15,	14,	2,	3,	12]
]

def des_sbox7(input_bits):
    # Вхідний бітовий рядок "100001"
    first_bit = int(input_bits[0], 2)  # Перший біт для визначення рядка
    last_bit = int(input_bits[5], 2)   # Останній біт для визначення рядка
    middle_bits = input_bits[1:5]      # Середні 4 біти для стовпця

    # Рядок для S-блоку: перший та останній біти
    row = 2 * first_bit + last_bit
    # Стовпець для S-блоку: середні 4 біти
    column = int(middle_bits, 2)

    # Отримуємо результат заміни з таблиці S-блоку
    output = S7[row][column]
    return output

# Вхідний бітовий рядок
input_bits = "100001"

# Отримуємо результат
output = des_sbox7(input_bits)
print(f"Результат виходу S-блоку №7 для вхідного бітового рядка {input_bits}: {output}")
# Out:
# Результат виходу S-блоку №7 для вхідного бітового рядка 100001: 6

# %%
# AES S-Box for SubBytes step
S_BOX = [
    [0x63, 0x7C, 0x77, 0x7B, 0xF2, 0x6B, 0x6F, 0xC5, 0x30, 0x01, 0x67, 0x2B, 0xFE, 0xD7, 0xAB, 0x76],
        [0xCA, 0x82, 0xC9, 0x7D, 0xFA, 0x59, 0x47, 0xF0, 0xAD, 0xD4, 0xA2, 0xAF, 0x9C, 0xA4, 0x72, 0xC0],
        [0xB7, 0xFD, 0x93, 0x26, 0x36, 0x3F, 0xF7, 0xCC, 0x34, 0xA5, 0xE5, 0xF1, 0x71, 0xD8, 0x31, 0x15],
        [0x04, 0xC7, 0x23, 0xC3, 0x18, 0x96, 0x05, 0x9A, 0x07, 0x12, 0x80, 0xE2, 0xEB, 0x27, 0xB2, 0x75],
        [0x09, 0x83, 0x2C, 0x1A, 0x1B, 0x6E, 0x5A, 0xA0, 0x52, 0x3B, 0xD6, 0xB3, 0x29, 0xE3, 0x2F, 0x84],
        [0x53, 0xD1, 0x00, 0xED, 0x20, 0xFC, 0xB1, 0x5B, 0x6A, 0xCB, 0xBE, 0x39, 0x4A, 0x4C, 0x58, 0xCF],
        [0xD0, 0xEF, 0xAA, 0xFB, 0x43, 0x4D, 0x33, 0x85, 0x45, 0xF9, 0x02, 0x7F, 0x50, 0x3C, 0x9F, 0xA8],
        [0x51, 0xA3, 0x40, 0x8F, 0x92, 0x9D, 0x38, 0xF5, 0xBC, 0xB6, 0xDA, 0x21, 0x10, 0xFF, 0xF3, 0xD2],
        [0xCD, 0x0C, 0x13, 0xEC, 0x5F, 0x97, 0x44, 0x17, 0xC4, 0xA7, 0x7E, 0x3D, 0x64, 0x5D, 0x19, 0x73],
        [0x60, 0x81, 0x4F, 0xDC, 0x22, 0x2A, 0x90, 0x88, 0x46, 0xEE, 0xB8, 0x14, 0xDE, 0x5E, 0x0B, 0xDB],
        [0xE0, 0x32, 0x3A, 0x0A, 0x49, 0x06, 0x24, 0x5C, 0xC2, 0xD3, 0xAC, 0x62, 0x91, 0x95, 0xE4, 0x79],
        [0xE7, 0xC8, 0x37, 0x6D, 0x8D, 0xD5, 0x4E, 0xA9, 0x6C, 0x56, 0xF4, 0xEA, 0x65, 0x7A, 0xAE, 0x08],
        [0xBA, 0x78, 0x25, 0x2E, 0x1C, 0xA6, 0xB4, 0xC6, 0xE8, 0xDD, 0x74, 0x1F, 0x4B, 0xBD, 0x8B, 0x8A],
        [0x70, 0x3E, 0xB5, 0x66, 0x48, 0x03, 0xF6, 0x0E, 0x61, 0x35, 0x57, 0xB9, 0x86, 0xC1, 0x1D, 0x9E],
        [0xE1, 0xF8, 0x98, 0x11, 0x69, 0xD9, 0x8E, 0x94, 0x9B, 0x1E, 0x87, 0xE9, 0xCE, 0x55, 0x28, 0xDF],
        [0x8C, 0xA1, 0x89, 0x0D, 0xBF, 0xE6, 0x42, 0x68, 0x41, 0x99, 0x2D, 0x0F, 0xB0, 0x54, 0xBB, 0x16]
]
# Input state (Start of Round 1)
state_round_1 = [
    [0x32, 0x88, 0x54, 0x9C],
    [0xAE, 0x34, 0x3F, 0xE0],
    [0xE0, 0xDA, 0x88, 0x27],
    [0x7F, 0x4B, 0xAD, 0x77]
]
# Round 1 Key (Initial key for round 1)
round_1_key = [
    [0x2b, 0x28, 0xab, 0x09],
    [0x7e, 0xae, 0xf7, 0xcf],
    [0x15, 0xd2, 0x15, 0x4f],
    [0x16, 0xa6, 0x88, 0x3c]
]
round_2_key = [
    [0xa0, 0x88, 0x23, 0x2A],
    [0xfA, 0x54, 0xA3, 0x6C],
    [0xeE, 0x2C, 0x39, 0x76],
    [0x17, 0xB1, 0x39, 0x05]
]
# AddRoundKey: XOR the state with the round key
def add_round_key(state, key):
    return [
        [state[i][j] ^ key[i][j] for j in range(4)]
        for i in range(4)
    ]

# SubBytes: Apply the S-Box to each byte in the state
def sub_bytes(state):
    return [
        [S_BOX[state[i][j] // 0x10][state[i][j] % 0x10] for j in range(4)]
        for i in range(4)
    ]

# ShiftRows: Shift rows as per AES specification
def shift_rows(state):
    return [
        state[0],
        [state[1][1], state[1][2], state[1][3], state[1][0]],
        [state[2][2], state[2][3], state[2][0], state[2][1]],
        [state[3][3], state[3][0], state[3][1], state[3][2]]
    ]

def gf_mult(x, y):
    """Multiplication in GF(2^8)"""
    p = 0
    for i in range(8):
        if (y & 1) != 0:
            p ^= x
        high_bit = x & 0x80
        x <<= 1
        if high_bit != 0:
            x ^= 0x1b  # AES polynomial (x^8 + x^4 + x^3 + x + 1)
        y >>= 1
    return p & 0xFF  # Ensure the result fits within 8 bits

def mix_columns(state):
    """MixColumns transformation. """
    # Loop over each column
    for i in range(4):
        col = [state[j][i] for j in range(4)]  # Extract the i-th column
        
        # Temporary list to hold the new values for the column
        temp = [0] * 4
        
        # r0 = 02 * a0 + 03 * a1 + 01 * a2 + 01 * a3
        temp[0] = gf_mult(col[0], 0x02) ^ gf_mult(col[1], 0x03) ^ gf_mult(col[2], 0x01) ^ gf_mult(col[3], 0x01)
        
        # r1 = 01 * a0 + 02 * a1 + 03 * a2 + 01 * a3
        temp[1] = gf_mult(col[0], 0x01) ^ gf_mult(col[1], 0x02) ^ gf_mult(col[2], 0x03) ^ gf_mult(col[3], 0x01)
        
        # r2 = 01 * a0 + 01 * a1 + 02 * a2 + 03 * a3
        temp[2] = gf_mult(col[0], 0x01) ^ gf_mult(col[1], 0x01) ^ gf_mult(col[2], 0x02) ^ gf_mult(col[3], 0x03)
        
        # r3 = 03 * a0 + 01 * a1 + 01 * a2 + 02 * a3
        temp[3] = gf_mult(col[0], 0x03) ^ gf_mult(col[1], 0x01) ^ gf_mult(col[2], 0x01) ^ gf_mult(col[3], 0x02)
        
        # Store the result back into the state
        for j in range(4):
            state[j][i] = temp[j] & 0xFF  # Mask to ensure it's within the 8-bit range

    return state


# Main AES 1 round function with debugging
def aes_round(state, key):
   
    print("Initial State:")
    for row in state:
        print([hex(x) for x in row])
    
    state = add_round_key(state, key)
    print("After AddRoundKey:")
    for row in state:
        print([hex(x) for x in row])
    
    state = sub_bytes(state)
    print("After SubBytes:")
    for row in state:
        print([hex(x) for x in row])
    
    state = shift_rows(state)
    print("After ShiftRows:")
    for row in state:
        print([hex(x) for x in row])
    
    state = mix_columns(state)
    print("After MixColumns:")
    for row in state:
        print([hex(x) for x in row])
    
    state = add_round_key(state, round_2_key)  
    print("After Final AddRoundKey:")
    for row in state:
        print([hex(x) for x in row])
        
    print("ExpandedKey:")
    for row in round_2_key:
        print([hex(x) for x in row])
    return state

# Perform 1 AES round
state_after_round_1 = aes_round(state_round_1, round_1_key)
# Out:
# Initial State:
# ['0x32', '0x88', '0x54', '0x9c']
# ['0xae', '0x34', '0x3f', '0xe0']
# ['0xe0', '0xda', '0x88', '0x27']
# ['0x7f', '0x4b', '0xad', '0x77']
# After AddRoundKey:
# ['0x19', '0xa0', '0xff', '0x95']
# ['0xd0', '0x9a', '0xc8', '0x2f']
# ['0xf5', '0x8', '0x9d', '0x68']
# ['0x69', '0xed', '0x25', '0x4b']
# After SubBytes:
# ['0xd4', '0xe0', '0x16', '0x2a']
# ['0x70', '0xb8', '0xe8', '0x15']
# ['0xe6', '0x30', '0x5e', '0x45']
# ['0xf9', '0x55', '0x3f', '0xb3']
# After ShiftRows:
# ['0xd4', '0xe0', '0x16', '0x2a']
# ['0xb8', '0xe8', '0x15', '0x70']
# ['0x5e', '0x45', '0xe6', '0x30']
# ['0xb3', '0xf9', '0x55', '0x3f']
# After MixColumns:
# ['0x8d', '0x44', '0xa0', '0xcb']
# ['0xee', '0x1d', '0x58', '0xa5']
# ['0x1e', '0x92', '0x2b', '0x7b']
# ['0xfc', '0x7f', '0x63', '0x40']
# After Final AddRoundKey:
# ['0x2d', '0xcc', '0x83', '0xe1']
# ['0x14', '0x49', '0xfb', '0xc9']
# ['0xf0', '0xbe', '0x12', '0xd']
# ['0xeb', '0xce', '0x5a', '0x45']
# ExpandedKey:
# ...
